# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %%
password = quote_plus("12345")     # dummy password (enter your password)

engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost:3306/olist"
)

files = {
    'customers': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\raw\olist_customers_dataset.csv',
    'orders': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\raw\olist_orders_dataset.csv',
    'products': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\processed\olist_products_dataset_clean.csv',
    'order_items': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\processed\olist_order_items_dataset_clean.csv',
    'payments': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\raw\olist_order_payments_dataset.csv',
    'reviews': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\raw\olist_order_reviews_dataset.csv',
    'sellers': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\raw\olist_sellers_dataset.csv',
    'geolocation': r'C:\Users\admi\Desktop\Saachi\Projects\E-commerce Customer and Sales Analytics Platform\data\processed\olist_geolocation_dataset_clean.csv',
}

for table_name, path in files.items():
    df = pd.read_csv(path)

    df.to_sql(
        name=table_name,
        con=engine,
        if_exists='replace',
        index=False
    )

    print(f"{table_name} uploaded successfully.")
# Out:
# customers uploaded successfully.
# orders uploaded successfully.
# products uploaded successfully.
# order_items uploaded successfully.
# payments uploaded successfully.
# reviews uploaded successfully.
# sellers uploaded successfully.
# geolocation uploaded successfully.
